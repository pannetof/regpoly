# %% [markdown]
# # RMT64Gen — equidistribution demo
#
# Auto-stubbed by `docs/notebooks/families/_stamp.py`. The companion theory page is [`generators/RMT64Gen.md`](../../generators/RMT64Gen.md).
#
# Outline (per the Phase 7 skeleton):
#
# 1. Family overview + link to the matching theory page.
# 2. Construct a familiar parameter set sourced from the catalog.
# 3. Verify characteristic polynomial + full-period claim.
# 4. Compute equidistribution `d(1..L)` for those parameters.
# 5. Cross-check against published values from the paper.
# 6. Run a small search for new parameters of the same shape.
# 7. Report: best parameters, equidistribution profile, summary.
#
# This notebook is a stub — flesh out per-family quirks (SIMD lanes for SFMT/dSFMT/MTGP, dSFMT's double-precision splice, MELG's lagged tempering, etc.) by appending narrative cells AFTER the auto-stub block below.

# %%
# stamp:auto-generated
# Parameters cell — edit the library_id to point at a different catalog entry
FAMILY = 'RMT64Gen'
LIBRARY_ID = None

# %%
# stamp:auto-generated
# Driver cell — delegates to docs/notebooks/families/_runner.py
import sys
from pathlib import Path
# When the notebook is executed (Sphinx build, Jupyter Lab, nbmake),
# CWD is the notebook's directory — which is where _runner.py lives.
sys.path.insert(0, str(Path.cwd()))
from _runner import run_for_family

result = run_for_family(FAMILY, library_id=LIBRARY_ID)
print(result['summary'])
